# %% [markdown]
# # Power Analysis
#
# Visualize power consamption

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import utils

# %% [markdown]
# ## Load & Check Data

# %%
data = pd.read_csv('../python/log/log_tvset.csv', header=None, index_col=0, parse_dates=True)
data.head()
# Out:
#                                   1        2
# 0
# 2022-11-21 17:50:56.416836  21.4791  25.0865
# 2022-11-21 17:51:01.433490  18.8123  23.5472
# 2022-11-21 17:51:06.446232  20.4050  23.3716
# 2022-11-21 17:51:11.461582  19.6305  23.6642
# 2022-11-21 17:51:16.472833  20.8765  24.1128

# %% [markdown]
# ## Visualize Power Consamption

# %%
analyzer = utils.Analyzer(data)

# %%
analyzer.plot()

# %%
analyzer.plot_heatmap()

# %%
analyzer.plot_bar()

# %% [markdown]
# ## Estimate Monthly Cost

# %%
estimated_cost = analyzer.estimate_monthly_cost(kwh_price=30)
print('{:.1f} yen'.format(estimated_cost))
# Out:
# 1167.3 yen
